# %%
#import necessary library
import numpy as np # linear algebra
import pandas as pd # data manipulation and analysis
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization
sns.set_style('whitegrid') # set style for visualization
import warnings # ignore warnings
warnings.filterwarnings('ignore')

from initial_report import *

# %%
#import customer data
df_customer=pd.read_csv("cleaned_customer_data.csv")
df_customer.head()
# Out:
#                         customer_id became_member_on gender  age    income
# 0  0610b486422d4921ae7d2bf64640c50b       2017-07-15      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef       2017-05-09      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932       2018-04-26      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c       2018-02-09      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d       2017-11-11      M   58   51000.0

# %%
#get initial report
initial_report(df_customer)
# Out:
#  *** DATA CLEANING CHECKLIST ***
# ----------------------------------------
# *** Structure:
# - Total Rows: 14825
# - Total Columns: 5
# - Column Names: ['customer_id', 'became_member_on', 'gender', 'age', 'income']
#
# *** Data Types:
#   customer_id: object
#   became_member_on: object
#   gender: object
#   age: int64
#   income: float64
#
# *** Mixed Data Types:
#
# *** Distinct Values per Column:
#   customer_id: 14825
#   became_member_on: 1707
#   gender: 3
#   age: 84
#   income: 91
#
# *** Null Values and Percentages:
#
#
# *** Duplicates: 0
#
# *** Negative or Zero Values:
#
# *** Basic Statistics:
#                 age         income
# count  14825.000000   14825.000000
# mean      54.393524   65404.991568
# std       17.383705   21598.299410
# min       18.000000   30000.000000
# 25%       42.000000   49000.000000
# 50%       55.000000   64000.000000
# 75%       66.000000   80000.000000
# max      101.000000  120000.000000
#
# *** Category Description:
#                              customer_id became_member_on gender
# count                              14825            14825  14825
# unique                             14825             1707      3
# top     e4052622e5ba45a8b96b59aba68cf068       2017-08-19      M
# freq                                   1               39   8484
#
# *** Outliers (IQR method):
#   age: No outliers
#     Lower Bound: 6.00
#     Upper Bound: 102.00
#   income: No outliers
#     Lower Bound: 2500.00
#     Upper Bound: 126500.00
# ----------------------------------------

# %% [markdown]
# Problems:
# 1. became member on column is object type- [change to datetype]

# %%
# Convert 'became_member_on' to datetime
df_customer['became_member_on'] = pd.to_datetime(df_customer['became_member_on'])
print(df_customer['became_member_on'].dtype)
# Out:
# datetime64[ns]

# %%
# Create age group column
df_customer['age_group'] = np.select(
    [
        (df_customer['age'] >= 18) & (df_customer['age'] <= 34),
        (df_customer['age'] >= 35) & (df_customer['age'] <= 49),
        (df_customer['age'] >= 50) & (df_customer['age'] <= 64),
        (df_customer['age'] >= 65) & (df_customer['age'] <= 79),
        (df_customer['age'] >= 80) & (df_customer['age'] <= 110)
    ],
    [
        'Young Adult',
        'Middle Age Adult',
        'Older Adult',
        'Senior',
        'Elderly'
    ],
    default='Unknown'
)

#print
df_customer.head()
# Out:
#                         customer_id became_member_on gender  age    income  \
# 0  0610b486422d4921ae7d2bf64640c50b       2017-07-15      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef       2017-05-09      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932       2018-04-26      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c       2018-02-09      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d       2017-11-11      M   58   51000.0
#
#      age_group
# 0  Older Adult
# 1       Senior
# 2       Senior
# 3       Senior
# 4  Older Adult

# %%
#get value counts for age group
df_customer.age_group.value_counts()
# Out:
# age_group
# Older Adult         5150
# Senior              3164
# Middle Age Adult    3153
# Young Adult         2256
# Elderly             1102
# Name: count, dtype: int64

# %%
#create income group

bins = [0, 44000, 84000, float('inf')]
labels = ['Low Income', 'Middle Income', 'High Income']

df_customer['income_group'] = pd.cut(df_customer['income'], bins=bins, labels=labels, right=True)

#check dataframe
df_customer.head()
# Out:
#                         customer_id became_member_on gender  age    income  \
# 0  0610b486422d4921ae7d2bf64640c50b       2017-07-15      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef       2017-05-09      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932       2018-04-26      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c       2018-02-09      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d       2017-11-11      M   58   51000.0
#
#      age_group   income_group
# 0  Older Adult    High Income
# 1       Senior    High Income
# 2       Senior  Middle Income
# 3       Senior  Middle Income
# 4  Older Adult  Middle Income

# %%
#get value counts for income group
df_customer.income_group.value_counts()
# Out:
# income_group
# Middle Income    8941
# High Income      3015
# Low Income       2869
# Name: count, dtype: int64

# %%
#get gender percentage
gender_percent = (
    df_customer.groupby('gender').size() / len(df_customer) * 100
)
gender_percent=round(gender_percent,2)
print(gender_percent)
# Out:
# gender
# F    41.34
# M    57.23
# O     1.43
# dtype: float64

# %%
#create group for membership year
df_customer['membership_year'] = df_customer['became_member_on'].astype(str).str[:4].astype(int)
df_customer.head()
# Out:
#                         customer_id became_member_on gender  age    income  \
# 0  0610b486422d4921ae7d2bf64640c50b       2017-07-15      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef       2017-05-09      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932       2018-04-26      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c       2018-02-09      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d       2017-11-11      M   58   51000.0
#
#      age_group   income_group  membership_year
# 0  Older Adult    High Income             2017
# 1       Senior    High Income             2017
# 2       Senior  Middle Income             2018
# 3       Senior  Middle Income             2018
# 4  Older Adult  Middle Income             2017

# %%
#get value counts for membership year
df_customer.membership_year.value_counts()
# Out:
# membership_year
# 2017    5599
# 2018    3669
# 2016    3024
# 2015    1597
# 2014     662
# 2013     274
# Name: count, dtype: int64

# %%
#drop unnecessary columns
df_customer = df_customer.drop(columns=['became_member_on', 'age','income'])
df_customer.head()
# Out:
#                         customer_id gender    age_group   income_group  \
# 0  0610b486422d4921ae7d2bf64640c50b      F  Older Adult    High Income
# 1  78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 2  e2127556f4f64592b11af22de27a7932      M       Senior  Middle Income
# 3  389bc3fa690240e798340f5a15918d5c      M       Senior  Middle Income
# 4  2eeac8d8feae4a8cad5a6af0499a211d      M  Older Adult  Middle Income
#
#    membership_year
# 0             2017
# 1             2017
# 2             2018
# 3             2018
# 4             2017

# %%
#import customer data
df_event=pd.read_csv("cleaned_events.csv")
df_event.head()
# Out:
#                         customer_id           event  time  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received     0
# 1  a03223e636434f42ac4c3df47e8bac43  offer received     0
# 2  e2127556f4f64592b11af22de27a7932  offer received     0
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received     0
# 4  68617ca6246f4fbc85e91a2a49552598  offer received     0
#
#                            offer_id  amount  reward
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 2  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 3  fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN

# %%
#merge df_customer and df_event
df_customer_events = pd.merge(df_customer, df_event, on='customer_id', how='left')
df_customer_events.head()
# Out:
#                         customer_id gender    age_group income_group  \
# 0  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 1  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 2  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 3  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 4  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
#
#    membership_year           event  time                          offer_id  \
# 0             2017     transaction    18                               NaN
# 1             2017     transaction   144                               NaN
# 2             2017  offer received   408  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 3             2017  offer received   504  3f207df678b143eea3cee63160fa8bed
# 4             2017     transaction   528                               NaN
#
#    amount  reward
# 0   21.51     NaN
# 1   32.28     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4   23.22     NaN

# %%
df_customer_events.event.value_counts()
# Out:
# event
# transaction        123957
# offer received      66501
# offer viewed        49860
# offer completed     32070
# Name: count, dtype: int64

# %%
#total_transaction_amount
total_transaction_amount = df_customer_events['amount'].sum()
print(total_transaction_amount)
# Out:
# 1734942.4

# %%
# Average transaction_amount
avg_transaction_amount = df_customer_events['amount'].mean()

print(avg_transaction_amount)
# Out:
# 13.996324531894123

# %%
#get average spend per customer
distinct_customers_count = df_customer_events['customer_id'].nunique()
#Calculate the total transaction amount per customer
df_transactions=df_customer_events[df_customer_events.event=="transaction"]
total_transaction_amount = df_transactions['amount'].sum()
#get average
avg_spend_per_customer=total_transaction_amount/distinct_customers_count
print(avg_spend_per_customer)
# Out:
# 117.02815514333896

# %%
#total spend based on age group
total_spend_age_group=df_customer_events.groupby("age_group")["amount"].sum()
print(total_spend_age_group)
# Out:
# age_group
# Elderly             147026.37
# Middle Age Adult    343178.68
# Older Adult         652728.13
# Senior              401065.92
# Young Adult         190943.30
# Name: amount, dtype: float64

# %%
#average spend based on age group
avg_spend_age_group=df_customer_events.groupby("age_group")["amount"].mean()
print(avg_spend_age_group)
# Out:
# age_group
# Elderly             17.090128
# Middle Age Adult    12.425906
# Older Adult         16.323100
# Senior              16.326722
# Young Adult          8.236350
# Name: amount, dtype: float64

# %%
#no. of transaction based on age_group
number_of_trans_age_group=df_transactions.groupby("age_group")["event"].value_counts()
print(number_of_trans_age_group)
# Out:
# age_group         event
# Elderly           transaction     8603
# Middle Age Adult  transaction    27618
# Older Adult       transaction    39988
# Senior            transaction    24565
# Young Adult       transaction    23183
# Name: count, dtype: int64

# %%
#get transaction quantity by each customer
transactions_per_customer = df_transactions.groupby('customer_id').size().sort_values(ascending=False)
print(transactions_per_customer )
# Out:
# customer_id
# 79d9d4f86aca4bed9290350fb43817c2    36
# 8dbfa485249f409aa223a2130f40634a    36
# 94de646f7b6041228ca7dec82adb97d2    35
# 5e60c6aa3b834e44b822ea43a3efea26    32
# b1f4ece7d49342628a9ed77aee2cde58    32
#                                     ..
# 4f4777c7c22648f58098e89a34426e07     1
# f8eff6816be34191b76e9b4614ce5224     1
# 4eeaab922a754d58a14733cfd2952279     1
# 0f628df0d3fb4e1192f156de98ec4a0b     1
# f904dad31185443c909f7722c28e9840     1
# Length: 14492, dtype: int64

# %%
#total spend based on membership year
total_spend_mem_year=df_customer_events.groupby("membership_year")["amount"].sum()
print(total_spend_mem_year)
# Out:
# membership_year
# 2013     23375.98
# 2014     55311.60
# 2015    245725.55
# 2016    519551.67
# 2017    658287.36
# 2018    232690.24
# Name: amount, dtype: float64

# %%
#total spending by gender
df_customer_events.groupby("gender")["amount"].sum()
# Out:
# gender
# F    863695.00
# M    844890.86
# O     26356.54
# Name: amount, dtype: float64

# %%
df_customer_events.head()
# Out:
#                         customer_id gender    age_group income_group  \
# 0  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 1  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 2  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 3  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 4  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
#
#    membership_year           event  time                          offer_id  \
# 0             2017     transaction    18                               NaN
# 1             2017     transaction   144                               NaN
# 2             2017  offer received   408  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 3             2017  offer received   504  3f207df678b143eea3cee63160fa8bed
# 4             2017     transaction   528                               NaN
#
#    amount  reward
# 0   21.51     NaN
# 1   32.28     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4   23.22     NaN

# %%
df_customer_events.event.value_counts()
# Out:
# event
# transaction        123957
# offer received      66501
# offer viewed        49860
# offer completed     32070
# Name: count, dtype: int64

# %%
df_completed=df_customer_events[df_customer_events.event=="offer completed"]
df_completed.head()
# Out:
#                          customer_id gender    age_group   income_group  \
# 5   0610b486422d4921ae7d2bf64640c50b      F  Older Adult    High Income
# 9   78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 20  78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 21  78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 34  e2127556f4f64592b11af22de27a7932      M       Senior  Middle Income
#
#     membership_year            event  time                          offer_id  \
# 5              2017  offer completed   528  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 9              2017  offer completed   132  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 20             2017  offer completed   510  ae264e3637204a6fb9bb56bc8210ddfd
# 21             2017  offer completed   510  f19421c1d4aa40978ebb69ca19b0e20d
# 34             2018  offer completed   522  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#     amount  reward
# 5      NaN     5.0
# 9      NaN     5.0
# 20     NaN    10.0
# 21     NaN     5.0
# 34     NaN     5.0

# %%
#get rows where transaction time and completed time is same
matching_pairs = pd.merge(
    df_transactions[['customer_id', 'time']].drop_duplicates(),
    df_completed[['customer_id', 'time']].drop_duplicates(),
    on=['customer_id', 'time'],
    how='inner'
)
matching_pairs
# Out:
#                             customer_id  time
# 0      0610b486422d4921ae7d2bf64640c50b   528
# 1      78afa995795e4d85b5d9ceeca43f5fef   132
# 2      78afa995795e4d85b5d9ceeca43f5fef   510
# 3      e2127556f4f64592b11af22de27a7932   522
# 4      389bc3fa690240e798340f5a15918d5c    60
# ...                                 ...   ...
# 29576  9dc1421481194dcd9400aec7c9ae6366   360
# 29577  9dc1421481194dcd9400aec7c9ae6366   414
# 29578  9dc1421481194dcd9400aec7c9ae6366   594
# 29579  e4052622e5ba45a8b96b59aba68cf068    54
# 29580  e4052622e5ba45a8b96b59aba68cf068   480
#
# [29581 rows x 2 columns]

# %%
#filter df_customer_events
df_matching_rows = pd.merge(df_customer_events, matching_pairs, on=['customer_id', 'time'], how='inner')
df_matching_rows
# Out:
#                             customer_id gender    age_group   income_group  \
# 0      0610b486422d4921ae7d2bf64640c50b      F  Older Adult    High Income
# 1      0610b486422d4921ae7d2bf64640c50b      F  Older Adult    High Income
# 2      78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 3      78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 4      78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# ...                                 ...    ...          ...            ...
# 66770  9dc1421481194dcd9400aec7c9ae6366      F      Elderly  Middle Income
# 66771  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
# 66772  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
# 66773  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
# 66774  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
#
#        membership_year            event  time  \
# 0                 2017      transaction   528
# 1                 2017  offer completed   528
# 2                 2017      transaction   132
# 3                 2017  offer completed   132
# 4                 2017      transaction   510
# ...                ...              ...   ...
# 66770             2016  offer completed   594
# 66771             2017      transaction    54
# 66772             2017  offer completed    54
# 66773             2017      transaction   480
# 66774             2017  offer completed   480
#
#                                offer_id  amount  reward
# 0                                   NaN   23.22     NaN
# 1      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     5.0
# 2                                   NaN   19.89     NaN
# 3      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     5.0
# 4                                   NaN   21.72     NaN
# ...                                 ...     ...     ...
# 66770  ae264e3637204a6fb9bb56bc8210ddfd     NaN    10.0
# 66771                               NaN   21.55     NaN
# 66772  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN     3.0
# 66773                               NaN   30.57     NaN
# 66774  f19421c1d4aa40978ebb69ca19b0e20d     NaN     5.0
#
# [66775 rows x 10 columns]

# %%
#get only the transaction and completed event
df_final=df_matching_rows[df_matching_rows.event.isin(["transaction","offer completed"])]
df_final
# Out:
#                             customer_id gender    age_group   income_group  \
# 0      0610b486422d4921ae7d2bf64640c50b      F  Older Adult    High Income
# 1      0610b486422d4921ae7d2bf64640c50b      F  Older Adult    High Income
# 2      78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 3      78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 4      78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# ...                                 ...    ...          ...            ...
# 66770  9dc1421481194dcd9400aec7c9ae6366      F      Elderly  Middle Income
# 66771  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
# 66772  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
# 66773  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
# 66774  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
#
#        membership_year            event  time  \
# 0                 2017      transaction   528
# 1                 2017  offer completed   528
# 2                 2017      transaction   132
# 3                 2017  offer completed   132
# 4                 2017      transaction   510
# ...                ...              ...   ...
# 66770             2016  offer completed   594
# 66771             2017      transaction    54
# 66772             2017  offer completed    54
# 66773             2017      transaction   480
# 66774             2017  offer completed   480
#
#                                offer_id  amount  reward
# 0                                   NaN   23.22     NaN
# 1      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     5.0
# 2                                   NaN   19.89     NaN
# 3      9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     5.0
# 4                                   NaN   21.72     NaN
# ...                                 ...     ...     ...
# 66770  ae264e3637204a6fb9bb56bc8210ddfd     NaN    10.0
# 66771                               NaN   21.55     NaN
# 66772  2298d6c36e964ae4a3e7e9706d1fb8c2     NaN     3.0
# 66773                               NaN   30.57     NaN
# 66774  f19421c1d4aa40978ebb69ca19b0e20d     NaN     5.0
#
# [61651 rows x 10 columns]

# %%
#how many transaction from offers
df_final.event.value_counts()
# Out:
# event
# offer completed    32070
# transaction        29581
# Name: count, dtype: int64

# %%
#total spend for transaction
df_final["amount"].sum()
# Out:
# np.float64(606355.75)

# %%
#total reward 
df_final["reward"].sum()
# Out:
# np.float64(158630.0)

# %%
#import offer data
df_offer=pd.read_csv("cleaned_offers.csv")
df_offer.head()
# Out:
#                            offer_id     offer_type  difficulty  reward  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo          10      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo          10      10
# 2  3f207df678b143eea3cee63160fa8bed  informational           0       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo           5       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount          20       5
#
#    duration                              channels
# 0         7         ['email', 'mobile', 'social']
# 1         5  ['web', 'email', 'mobile', 'social']
# 2         4            ['web', 'email', 'mobile']
# 3         7            ['web', 'email', 'mobile']
# 4        10                      ['web', 'email']

# %%
# Convert the numerical columns to strings before concatenating
df_offer['difficulty'] = df_offer['difficulty'].astype(str)
df_offer['reward'] = df_offer['reward'].astype(str)
df_offer['duration'] = df_offer['duration'].astype(str)

# Create the new column by concatenating the strings with hyphens
df_offer['offer_key'] = (
    df_offer['offer_type'] + '-' + 
    df_offer['difficulty'] + '-' + 
    df_offer['reward'] + '-' + 
    df_offer['duration']
)

# Display the DataFrame with the new column
print("DataFrame with the new 'offer_key' column:")
print(df_offer[['offer_id', 'offer_key']].head())
# Out:
# DataFrame with the new 'offer_key' column:
#                            offer_id            offer_key
# 0  ae264e3637204a6fb9bb56bc8210ddfd         bogo-10-10-7
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0         bogo-10-10-5
# 2  3f207df678b143eea3cee63160fa8bed  informational-0-0-4
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo-5-5-7
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7     discount-20-5-10

# %%
#load df_offer
df_offer.head()
# Out:
#                            offer_id     offer_type difficulty reward duration  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo         10     10        7
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo         10     10        5
# 2  3f207df678b143eea3cee63160fa8bed  informational          0      0        4
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo          5      5        7
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount         20      5       10
#
#                                channels            offer_key
# 0         ['email', 'mobile', 'social']         bogo-10-10-7
# 1  ['web', 'email', 'mobile', 'social']         bogo-10-10-5
# 2            ['web', 'email', 'mobile']  informational-0-0-4
# 3            ['web', 'email', 'mobile']           bogo-5-5-7
# 4                      ['web', 'email']     discount-20-5-10

# %%
#merge df_final and df_offer
#merge df_customer and df_event
df_final_offers = pd.merge(df_final, df_offer, on='offer_id', how='left')
df_final_offers.head()
# Out:
#                         customer_id gender    age_group income_group  \
# 0  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 1  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 2  78afa995795e4d85b5d9ceeca43f5fef      F       Senior  High Income
# 3  78afa995795e4d85b5d9ceeca43f5fef      F       Senior  High Income
# 4  78afa995795e4d85b5d9ceeca43f5fef      F       Senior  High Income
#
#    membership_year            event  time                          offer_id  \
# 0             2017      transaction   528                               NaN
# 1             2017  offer completed   528  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 2             2017      transaction   132                               NaN
# 3             2017  offer completed   132  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4             2017      transaction   510                               NaN
#
#    amount  reward_x offer_type difficulty reward_y duration  \
# 0   23.22       NaN        NaN        NaN      NaN      NaN
# 1     NaN       5.0       bogo          5        5        7
# 2   19.89       NaN        NaN        NaN      NaN      NaN
# 3     NaN       5.0       bogo          5        5        7
# 4   21.72       NaN        NaN        NaN      NaN      NaN
#
#                      channels   offer_key
# 0                         NaN         NaN
# 1  ['web', 'email', 'mobile']  bogo-5-5-7
# 2                         NaN         NaN
# 3  ['web', 'email', 'mobile']  bogo-5-5-7
# 4                         NaN         NaN

# %%
#initial_report of df_final_offers
initial_report(df_final_offers)
# Out:
#  *** DATA CLEANING CHECKLIST ***
# ----------------------------------------
# *** Structure:
# - Total Rows: 61651
# - Total Columns: 16
# - Column Names: ['customer_id', 'gender', 'age_group', 'income_group', 'membership_year', 'event', 'time', 'offer_id', 'amount', 'reward_x', 'offer_type', 'difficulty', 'reward_y', 'duration', 'channels', 'offer_key']
#
# *** Data Types:
#   customer_id: object
#   gender: object
#   age_group: object
#   income_group: category
#   membership_year: int64
#   event: object
#   time: int64
#   offer_id: object
#   amount: float64
#   reward_x: float64
#   offer_type: object
#   difficulty: object
#   reward_y: object
#   duration: object
#   channels: object
#   offer_key: object
#
# *** Mixed Data Types:
#   offer_id:
#     - str: 32070
#     - float: 29581
#   offer_type:
#     - str: 32070
#     - float: 29581
#   difficulty:
#     - str: 32070
#     - float: 29581
#   reward_y:
#     - str: 32070
#     - float: 29581
#   duration:
#     - str: 32070
#     - float: 29581
#   channels:
#     - str: 32070
#     - float: 29581
#   offer_key:
#     - str: 32070
#     - float: 29581
#
# *** Distinct Values per Column:
#   customer_id: 11986
#   gender: 3
#   age_group: 5
#   income_group: 3
#   membership_year: 6
#   event: 2
#   time: 120
#   offer_id: 8
#   amount: 4279
#   reward_x: 4
#   offer_type: 2
#   difficulty: 4
#   reward_y: 4
#   duration: 3
#   channels: 4
#   offer_key: 8
#
# *** Null Values and Percentages:
#   offer_id: Missing Values: 29581, Pct: 47.981%
#   amount: Missing Values: 32070, Pct: 52.019%
#   reward_x: Missing Values: 29581, Pct: 47.981%
#   offer_type: Missing Values: 29581, Pct: 47.981%
#   difficulty: Missing Values: 29581, Pct: 47.981%
#   reward_y: Missing Values: 29581, Pct: 47.981%
#   duration: Missing Values: 29581, Pct: 47.981%
#   channels: Missing Values: 29581, Pct: 47.981%
#   offer_key: Missing Values: 29581, Pct: 47.981%
#
#
# *** Duplicates: 0
#
# *** Negative or Zero Values:
#   time: 408
#
# *** Basic Statistics:
#        membership_year          time        amount      reward_x
# count     61651.000000  61651.000000  29581.000000  32070.000000
# mean       2016.421502    393.926262     20.498149      4.946367
# std           1.131277    194.247869     40.026325      2.905766
# min        2013.000000      0.000000      0.150000      2.000000
# 25%        2016.000000    228.000000     11.250000      2.000000
# 50%        2017.000000    426.000000     16.860000      5.000000
# 75%        2017.000000    558.000000     23.430000      5.000000
# max        2018.000000    714.000000   1015.730000     10.000000
#
# *** Category Description:
#                              customer_id gender    age_group            event  \
# count                              61651  61651        61651            61651
# unique                             11986      3            5                2
# top     2ddc7d63c32d4606a7a45e3e70439b44      M  Older Adult  offer completed
# freq                                  12  31306        22804            32070
#
#                                 offer_id offer_type difficulty reward_y  \
# count                              32070      32070      32070    32070
# unique                                 8          2          4        4
# top     fafdcd668e3743c1bb461111dcafc2a4   discount         10        5
# freq                                4957      16970      15702    11521
#
#        duration                              channels         offer_key
# count     32070                                 32070             32070
# unique        3                                     4                 8
# top           7  ['web', 'email', 'mobile', 'social']  discount-10-2-10
# freq      16452                                 17159              4957
#
# *** Outliers (IQR method):
#   membership_year: 3598 outliers
#     Lower Bound: 2014.50
#     Upper Bound: 2018.50
#   time: No outliers
#     Lower Bound: -267.00
#     Upper Bound: 1053.00
#   amount: 484 outliers
#     Lower Bound: -7.02
#     Upper Bound: 41.70
#   reward_x: 6885 outliers
#     Lower Bound: -2.50
#     Upper Bound: 9.50
# ----------------------------------------

# %%
#check whether reward_x and reward_y is same
df_final_offers['reward_y'] = pd.to_numeric(df_final_offers['reward_y'], errors='coerce')
df_not_same = df_final_offers[df_final_offers['reward_x'] != df_final_offers['reward_y']]

df_not_same
# Out:
#                             customer_id gender    age_group   income_group  \
# 0      0610b486422d4921ae7d2bf64640c50b      F  Older Adult    High Income
# 2      78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 4      78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 7      e2127556f4f64592b11af22de27a7932      M       Senior  Middle Income
# 10     389bc3fa690240e798340f5a15918d5c      M       Senior  Middle Income
# ...                                 ...    ...          ...            ...
# 61641  9dc1421481194dcd9400aec7c9ae6366      F      Elderly  Middle Income
# 61643  9dc1421481194dcd9400aec7c9ae6366      F      Elderly  Middle Income
# 61645  9dc1421481194dcd9400aec7c9ae6366      F      Elderly  Middle Income
# 61647  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
# 61649  e4052622e5ba45a8b96b59aba68cf068      F  Older Adult  Middle Income
#
#        membership_year        event  time offer_id  amount  reward_x  \
# 0                 2017  transaction   528      NaN   23.22       NaN
# 2                 2017  transaction   132      NaN   19.89       NaN
# 4                 2017  transaction   510      NaN   21.72       NaN
# 7                 2018  transaction   522      NaN   18.42       NaN
# 10                2018  transaction    60      NaN    9.54       NaN
# ...                ...          ...   ...      ...     ...       ...
# 61641             2016  transaction   360      NaN   10.75       NaN
# 61643             2016  transaction   414      NaN   11.03       NaN
# 61645             2016  transaction   594      NaN   12.57       NaN
# 61647             2017  transaction    54      NaN   21.55       NaN
# 61649             2017  transaction   480      NaN   30.57       NaN
#
#       offer_type difficulty  reward_y duration channels offer_key
# 0            NaN        NaN       NaN      NaN      NaN       NaN
# 2            NaN        NaN       NaN      NaN      NaN       NaN
# 4            NaN        NaN       NaN      NaN      NaN       NaN
# 7            NaN        NaN       NaN      NaN      NaN       NaN
# 10           NaN        NaN       NaN      NaN      NaN       NaN
# ...          ...        ...       ...      ...      ...       ...
# 61641        NaN        NaN       NaN      NaN      NaN       NaN
# 61643        NaN        NaN       NaN      NaN      NaN       NaN
# 61645        NaN        NaN       NaN      NaN      NaN       NaN
# 61647        NaN        NaN       NaN      NaN      NaN       NaN
# 61649        NaN        NaN       NaN      NaN      NaN       NaN
#
# [29581 rows x 16 columns]

# %%
#drop reward_y and rename reward_x to reward
df_final_offers = df_final_offers.drop(columns=['reward_y'])
df_final_offers.rename(columns={'reward_x': 'reward'}, inplace=True)
df_final_offers.head()
# Out:
#                         customer_id gender    age_group income_group  \
# 0  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 1  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 2  78afa995795e4d85b5d9ceeca43f5fef      F       Senior  High Income
# 3  78afa995795e4d85b5d9ceeca43f5fef      F       Senior  High Income
# 4  78afa995795e4d85b5d9ceeca43f5fef      F       Senior  High Income
#
#    membership_year            event  time                          offer_id  \
# 0             2017      transaction   528                               NaN
# 1             2017  offer completed   528  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 2             2017      transaction   132                               NaN
# 3             2017  offer completed   132  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 4             2017      transaction   510                               NaN
#
#    amount  reward offer_type difficulty duration                    channels  \
# 0   23.22     NaN        NaN        NaN      NaN                         NaN
# 1     NaN     5.0       bogo          5        7  ['web', 'email', 'mobile']
# 2   19.89     NaN        NaN        NaN      NaN                         NaN
# 3     NaN     5.0       bogo          5        7  ['web', 'email', 'mobile']
# 4   21.72     NaN        NaN        NaN      NaN                         NaN
#
#     offer_key
# 0         NaN
# 1  bogo-5-5-7
# 2         NaN
# 3  bogo-5-5-7
# 4         NaN

# %%
#which offer type was more succesful
df_final_offers.offer_type.value_counts()
# Out:
# offer_type
# discount    16970
# bogo        15100
# Name: count, dtype: int64

# %%
#which offer key was more succesful
df_final_offers.offer_key.value_counts()
# Out:
# offer_key
# discount-10-2-10    4957
# discount-7-3-7      4847
# bogo-5-5-7          4141
# bogo-5-5-5          4074
# discount-10-2-7     3860
# bogo-10-10-7        3604
# discount-20-5-10    3306
# bogo-10-10-5        3281
# Name: count, dtype: int64
