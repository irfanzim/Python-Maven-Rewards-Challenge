# %%
#import necessary library
import numpy as np # linear algebra
import pandas as pd # data manipulation and analysis
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization
sns.set_style('whitegrid') # set style for visualization
import warnings # ignore warnings
warnings.filterwarnings('ignore')

from initial_report import *

# %%
#import customer data
df_customer=pd.read_csv("cleaned_customer_data.csv")
df_customer.head()
# Out:
#                         customer_id became_member_on gender  age    income
# 0  0610b486422d4921ae7d2bf64640c50b       2017-07-15      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef       2017-05-09      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932       2018-04-26      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c       2018-02-09      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d       2017-11-11      M   58   51000.0

# %%
#get initial report
initial_report(df_customer)
# Out:
#  *** DATA CLEANING CHECKLIST ***
# ----------------------------------------
# *** Structure:
# - Total Rows: 14825
# - Total Columns: 5
# - Column Names: ['customer_id', 'became_member_on', 'gender', 'age', 'income']
#
# *** Data Types:
#   customer_id: object
#   became_member_on: object
#   gender: object
#   age: int64
#   income: float64
#
# *** Mixed Data Types:
#
# *** Distinct Values per Column:
#   customer_id: 14825
#   became_member_on: 1707
#   gender: 3
#   age: 84
#   income: 91
#
# *** Null Values and Percentages:
#
#
# *** Duplicates: 0
#
# *** Negative or Zero Values:
#
# *** Basic Statistics:
#                 age         income
# count  14825.000000   14825.000000
# mean      54.393524   65404.991568
# std       17.383705   21598.299410
# min       18.000000   30000.000000
# 25%       42.000000   49000.000000
# 50%       55.000000   64000.000000
# 75%       66.000000   80000.000000
# max      101.000000  120000.000000
#
# *** Category Description:
#                              customer_id became_member_on gender
# count                              14825            14825  14825
# unique                             14825             1707      3
# top     e4052622e5ba45a8b96b59aba68cf068       2017-08-19      M
# freq                                   1               39   8484
#
# *** Outliers (IQR method):
#   age: No outliers
#     Lower Bound: 6.00
#     Upper Bound: 102.00
#   income: No outliers
#     Lower Bound: 2500.00
#     Upper Bound: 126500.00
# ----------------------------------------

# %% [markdown]
# Problems:
# 1. became member on column is object type- [change to datetype]

# %%
# Convert 'became_member_on' to datetime
df_customer['became_member_on'] = pd.to_datetime(df_customer['became_member_on'])
print(df_customer['became_member_on'].dtype)
# Out:
# datetime64[ns]

# %%
# Create age group column
df_customer['age_group'] = np.select(
    [
        (df_customer['age'] >= 18) & (df_customer['age'] <= 34),
        (df_customer['age'] >= 35) & (df_customer['age'] <= 49),
        (df_customer['age'] >= 50) & (df_customer['age'] <= 64),
        (df_customer['age'] >= 65) & (df_customer['age'] <= 79),
        (df_customer['age'] >= 80) & (df_customer['age'] <= 110)
    ],
    [
        'Young Adult',
        'Middle Age Adult',
        'Older Adult',
        'Senior',
        'Elderly'
    ],
    default='Unknown'
)

#print
df_customer.head()
# Out:
#                         customer_id became_member_on gender  age    income  \
# 0  0610b486422d4921ae7d2bf64640c50b       2017-07-15      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef       2017-05-09      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932       2018-04-26      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c       2018-02-09      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d       2017-11-11      M   58   51000.0
#
#      age_group
# 0  Older Adult
# 1       Senior
# 2       Senior
# 3       Senior
# 4  Older Adult

# %%
#get value counts for age group
df_customer.age_group.value_counts()
# Out:
# age_group
# Older Adult         5150
# Senior              3164
# Middle Age Adult    3153
# Young Adult         2256
# Elderly             1102
# Name: count, dtype: int64

# %%
#create income group

bins = [0, 44000, 84000, float('inf')]
labels = ['Low Income', 'Middle Income', 'High Income']

df_customer['income_group'] = pd.cut(df_customer['income'], bins=bins, labels=labels, right=True)

#check dataframe
df_customer.head()
# Out:
#                         customer_id became_member_on gender  age    income  \
# 0  0610b486422d4921ae7d2bf64640c50b       2017-07-15      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef       2017-05-09      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932       2018-04-26      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c       2018-02-09      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d       2017-11-11      M   58   51000.0
#
#      age_group   income_group
# 0  Older Adult    High Income
# 1       Senior    High Income
# 2       Senior  Middle Income
# 3       Senior  Middle Income
# 4  Older Adult  Middle Income

# %%
#get value counts for income group
df_customer.income_group.value_counts()
# Out:
# income_group
# Middle Income    8941
# High Income      3015
# Low Income       2869
# Name: count, dtype: int64

# %%
#get gender percentage
gender_percent = (
    df_customer.groupby('gender').size() / len(df_customer) * 100
)
gender_percent=round(gender_percent,2)
print(gender_percent)
# Out:
# gender
# F    41.34
# M    57.23
# O     1.43
# dtype: float64

# %%
#create group for membership year
df_customer['membership_year'] = df_customer['became_member_on'].astype(str).str[:4].astype(int)
df_customer.head()
# Out:
#                         customer_id became_member_on gender  age    income  \
# 0  0610b486422d4921ae7d2bf64640c50b       2017-07-15      F   55  112000.0
# 1  78afa995795e4d85b5d9ceeca43f5fef       2017-05-09      F   75  100000.0
# 2  e2127556f4f64592b11af22de27a7932       2018-04-26      M   68   70000.0
# 3  389bc3fa690240e798340f5a15918d5c       2018-02-09      M   65   53000.0
# 4  2eeac8d8feae4a8cad5a6af0499a211d       2017-11-11      M   58   51000.0
#
#      age_group   income_group  membership_year
# 0  Older Adult    High Income             2017
# 1       Senior    High Income             2017
# 2       Senior  Middle Income             2018
# 3       Senior  Middle Income             2018
# 4  Older Adult  Middle Income             2017

# %%
#get value counts for membership year
df_customer.membership_year.value_counts()
# Out:
# membership_year
# 2017    5599
# 2018    3669
# 2016    3024
# 2015    1597
# 2014     662
# 2013     274
# Name: count, dtype: int64

# %%
#drop unnecessary columns
df_customer_bins = df_customer.drop(columns=['became_member_on', 'age','income'])
df_customer_bins.head()
# Out:
#                         customer_id gender    age_group   income_group  \
# 0  0610b486422d4921ae7d2bf64640c50b      F  Older Adult    High Income
# 1  78afa995795e4d85b5d9ceeca43f5fef      F       Senior    High Income
# 2  e2127556f4f64592b11af22de27a7932      M       Senior  Middle Income
# 3  389bc3fa690240e798340f5a15918d5c      M       Senior  Middle Income
# 4  2eeac8d8feae4a8cad5a6af0499a211d      M  Older Adult  Middle Income
#
#    membership_year
# 0             2017
# 1             2017
# 2             2018
# 3             2018
# 4             2017

# %%
#import event data
df_event=pd.read_csv("cleaned_events.csv")
df_event.head()
# Out:
#                         customer_id           event  time  \
# 0  78afa995795e4d85b5d9ceeca43f5fef  offer received     0
# 1  a03223e636434f42ac4c3df47e8bac43  offer received     0
# 2  e2127556f4f64592b11af22de27a7932  offer received     0
# 3  8ec6ce2a7e7949b1bf142def7d0e0586  offer received     0
# 4  68617ca6246f4fbc85e91a2a49552598  offer received     0
#
#                            offer_id  amount  reward
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7     NaN     NaN
# 2  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 3  fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0     NaN     NaN

# %%
#merge df_customer_bins and df_event
df_customer_events = pd.merge(df_customer_bins, df_event, on='customer_id', how='left')
df_customer_events.head()
# Out:
#                         customer_id gender    age_group income_group  \
# 0  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 1  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 2  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 3  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 4  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
#
#    membership_year           event  time                          offer_id  \
# 0             2017     transaction    18                               NaN
# 1             2017     transaction   144                               NaN
# 2             2017  offer received   408  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 3             2017  offer received   504  3f207df678b143eea3cee63160fa8bed
# 4             2017     transaction   528                               NaN
#
#    amount  reward
# 0   21.51     NaN
# 1   32.28     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4   23.22     NaN

# %%
initial_report(df_customer_events)
# Out:
#  *** DATA CLEANING CHECKLIST ***
# ----------------------------------------
# *** Structure:
# - Total Rows: 272388
# - Total Columns: 10
# - Column Names: ['customer_id', 'gender', 'age_group', 'income_group', 'membership_year', 'event', 'time', 'offer_id', 'amount', 'reward']
#
# *** Data Types:
#   customer_id: object
#   gender: object
#   age_group: object
#   income_group: category
#   membership_year: int64
#   event: object
#   time: int64
#   offer_id: object
#   amount: float64
#   reward: float64
#
# *** Mixed Data Types:
#   offer_id:
#     - str: 148431
#     - float: 123957
#
# *** Distinct Values per Column:
#   customer_id: 14825
#   gender: 3
#   age_group: 5
#   income_group: 3
#   membership_year: 6
#   event: 4
#   time: 120
#   offer_id: 10
#   amount: 5036
#   reward: 4
#
# *** Null Values and Percentages:
#   offer_id: Missing Values: 123957, Pct: 45.508%
#   amount: Missing Values: 148431, Pct: 54.492%
#   reward: Missing Values: 240318, Pct: 88.226%
#
#
# *** Duplicates: 0
#
# *** Negative or Zero Values:
#   time: 13545
#
# *** Basic Statistics:
#        membership_year           time         amount        reward
# count    272388.000000  272388.000000  123957.000000  32070.000000
# mean       2016.457351     366.498965      13.996325      4.946367
# std           1.218782     200.382563      31.749420      2.905766
# min        2013.000000       0.000000       0.050000      2.000000
# 25%        2016.000000     186.000000       3.660000      2.000000
# 50%        2017.000000     408.000000      10.800000      5.000000
# 75%        2017.000000     528.000000      19.130000      5.000000
# max        2018.000000     714.000000    1062.280000     10.000000
#
# *** Category Description:
#                              customer_id  gender    age_group        event  \
# count                             272388  272388       272388       272388
# unique                             14825       3            5            4
# top     94de646f7b6041228ca7dec82adb97d2       M  Older Adult  transaction
# freq                                  51  155483        92540       123957
#
#                                 offer_id
# count                             148431
# unique                                10
# top     fafdcd668e3743c1bb461111dcafc2a4
# freq                               18016
#
# *** Outliers (IQR method):
#   membership_year: 20828 outliers
#     Lower Bound: 2014.50
#     Upper Bound: 2018.50
#   time: No outliers
#     Lower Bound: -327.00
#     Upper Bound: 1041.00
#   amount: 1001 outliers
#     Lower Bound: -19.54
#     Upper Bound: 42.33
#   reward: 6885 outliers
#     Lower Bound: -2.50
#     Upper Bound: 9.50
# ----------------------------------------

# %%
df_customer_events.event.value_counts()
# Out:
# event
# transaction        123957
# offer received      66501
# offer viewed        49860
# offer completed     32070
# Name: count, dtype: int64

# %%
#percentage of offer_viewed and completed

# Calculate the value counts and get the total sum
event_counts = df_customer_events['event'].value_counts()

# Get the count for 'offer completed' and 'offer viewed'
offer_received_count = event_counts.get('offer received', 0)
offer_completed_count = event_counts.get('offer completed', 0)
offer_viewed_count = event_counts.get('offer viewed', 0)

# Calculate the percentages
offer_completed_percentage = (offer_completed_count / offer_received_count) * 100
offer_viewed_percentage = (offer_viewed_count / offer_received_count) * 100
offer_completed_after_view=(offer_completed_count / offer_viewed_count) * 100

# Print the results
print(f"Offer Viewed after offer received: {offer_viewed_percentage:.2f}%")
print(f"Offer Completed after offer received: {offer_completed_percentage:.2f}%")
print(f"Offer Completed after offer viewed: {offer_completed_after_view:.2f}%")
# Out:
# Offer Viewed after offer received: 74.98%
# Offer Completed after offer received: 48.22%
# Offer Completed after offer viewed: 64.32%

# %%
#total_transaction_amount
total_transaction_amount = df_customer_events['amount'].sum()
print(total_transaction_amount)
# Out:
# 1734942.4

# %%
# Average transaction_amount
avg_transaction_amount = df_customer_events['amount'].mean()
print(avg_transaction_amount)
# Out:
# 13.996324531894123

# %%
#get average spend per customer
distinct_customers_count = df_customer_events['customer_id'].nunique()
#get average
avg_spend_per_customer=total_transaction_amount/distinct_customers_count
print(avg_spend_per_customer)
# Out:
# 117.02815514333895

# %%
#total spend based on age group
total_spend_age_group=df_customer_events.groupby("age_group")["amount"].sum().sort_values(ascending=False)
print(total_spend_age_group)
# Out:
# age_group
# Older Adult         652728.13
# Senior              401065.92
# Middle Age Adult    343178.68
# Young Adult         190943.30
# Elderly             147026.37
# Name: amount, dtype: float64

# %%
#average spend by age group
age_group_count= df_customer_events.groupby("age_group")["customer_id"].nunique()
avg_spend_age_group=total_spend_age_group/age_group_count.sort_values(ascending=False)
print(avg_spend_age_group)
# Out:
# age_group
# Older Adult         126.743326
# Senior              126.759140
# Middle Age Adult    108.841954
# Young Adult          84.637988
# Elderly             133.417759
# dtype: float64

# %%
#no. of transaction based on age_group
df_transaction=df_customer_events[df_customer_events.event=="transaction"]
number_of_trans_age_group=df_transaction.groupby("age_group")["event"].size().sort_values(ascending=False)
print(number_of_trans_age_group)
# Out:
# age_group
# Older Adult         39988
# Middle Age Adult    27618
# Senior              24565
# Young Adult         23183
# Elderly              8603
# Name: event, dtype: int64

# %%
#average transaction amount by age group
avg_transaction_amount_age_group=df_customer_events.groupby("age_group")["amount"].mean()
print(avg_transaction_amount_age_group)
# Out:
# age_group
# Elderly             17.090128
# Middle Age Adult    12.425906
# Older Adult         16.323100
# Senior              16.326722
# Young Adult          8.236350
# Name: amount, dtype: float64

# %%
#total spend based on membership year
total_spend_mem_year=df_customer_events.groupby("membership_year")["amount"].sum().sort_values(ascending=False)
print(total_spend_mem_year)
# Out:
# membership_year
# 2017    658287.36
# 2016    519551.67
# 2015    245725.55
# 2018    232690.24
# 2014     55311.60
# 2013     23375.98
# Name: amount, dtype: float64

# %%
#total transaction based on income_group
total_spend_income_group=df_customer_events.groupby("income_group")["amount"].sum().sort_values(ascending=False)
print(total_spend_income_group)
# Out:
# income_group
# Middle Income    1003664.00
# High Income       547875.48
# Low Income        183402.92
# Name: amount, dtype: float64

# %%
#average transaciton amount by income group
income_group_count= df_customer_events.groupby("income_group")["customer_id"].nunique()
avg_spend_income_group=total_spend_income_group/income_group_count.sort_values(ascending=False)
print(avg_spend_income_group)
# Out:
# income_group
# Middle Income    112.254110
# High Income      181.716577
# Low Income        63.925730
# dtype: float64

# %%
#no. of transaction based on income_group
number_of_trans_income_group=df_transaction.groupby("income_group")["event"].size().sort_values(ascending=False)
print(number_of_trans_income_group)
# Out:
# income_group
# Middle Income    76169
# Low Income       28905
# High Income      18883
# Name: event, dtype: int64

# %%
#average transaction value by income group
avg_transaction_value_income_group=df_customer_events.groupby("income_group")["amount"].mean()
print(avg_transaction_value_income_group)
# Out:
# income_group
# Low Income        6.345024
# Middle Income    13.176804
# High Income      29.014218
# Name: amount, dtype: float64

# %%
#total spending by gender
total_transaction_by_gender=df_customer_events.groupby("gender")["amount"].sum()
print(total_transaction_by_gender)
# Out:
# gender
# F    863695.00
# M    844890.86
# O     26356.54
# Name: amount, dtype: float64

# %%
#average transaciton amount by gender
gender_count= df_customer_events.groupby("gender")["customer_id"].nunique()
avg_trans_gender=total_transaction_by_gender/gender_count.sort_values(ascending=False)
print(avg_trans_gender)
# Out:
# gender
# F    140.919400
# M     99.586381
# O    124.323302
# dtype: float64

# %%
#no. of transaction based on gender
number_of_trans_gender=df_transaction.groupby("gender")["event"].size().sort_values(ascending=False)
print(number_of_trans_gender)
# Out:
# gender
# M    72794
# F    49382
# O     1781
# Name: event, dtype: int64

# %%
#average transaction value by gender
avg_transaction_value_gender=df_customer_events.groupby("gender")["amount"].mean()
print(avg_transaction_value_gender)
# Out:
# gender
# F    17.490077
# M    11.606600
# O    14.798731
# Name: amount, dtype: float64

# %%
df_customer_events.head()
# Out:
#                         customer_id gender    age_group income_group  \
# 0  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 1  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 2  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 3  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
# 4  0610b486422d4921ae7d2bf64640c50b      F  Older Adult  High Income
#
#    membership_year           event  time                          offer_id  \
# 0             2017     transaction    18                               NaN
# 1             2017     transaction   144                               NaN
# 2             2017  offer received   408  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 3             2017  offer received   504  3f207df678b143eea3cee63160fa8bed
# 4             2017     transaction   528                               NaN
#
#    amount  reward
# 0   21.51     NaN
# 1   32.28     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4   23.22     NaN

# %%
#sort by customer_id and time

df_sorted = df_customer_events.sort_values(by=["customer_id","offer_id", "time"], ascending=[True, True, True])

# Reset index for cleanliness
df_sorted = df_sorted.reset_index(drop=True)

df_sorted.head()
# Out:
#                         customer_id gender    age_group   income_group  \
# 0  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 1  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 2  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 3  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 4  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
#
#    membership_year            event  time                          offer_id  \
# 0             2017   offer received   576  2906b810c7d4411798c6938adc9daaa5
# 1             2017  offer completed   576  2906b810c7d4411798c6938adc9daaa5
# 2             2017   offer received   336  3f207df678b143eea3cee63160fa8bed
# 3             2017     offer viewed   372  3f207df678b143eea3cee63160fa8bed
# 4             2017   offer received   168  5a8bc65990b245e5a138643cd4eb9837
#
#    amount  reward
# 0     NaN     NaN
# 1     NaN     2.0
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %%
#check status from one customer_id
df_sorted[df_sorted.customer_id=="e2127556f4f64592b11af22de27a7932"]
# Out:
#                              customer_id gender age_group   income_group  \
# 240532  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240533  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240534  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240535  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240536  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240537  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240538  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240539  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240540  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240541  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240542  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
# 240543  e2127556f4f64592b11af22de27a7932      M    Senior  Middle Income
#
#         membership_year            event  time  \
# 240532             2018   offer received     0
# 240533             2018     offer viewed    18
# 240534             2018   offer received   336
# 240535             2018   offer received   408
# 240536             2018     offer viewed   420
# 240537             2018  offer completed   522
# 240538             2018   offer received   504
# 240539             2018     offer viewed   522
# 240540             2018  offer completed   522
# 240541             2018      transaction   288
# 240542             2018      transaction   294
# 240543             2018      transaction   522
#
#                                 offer_id  amount  reward
# 240532  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 240533  2906b810c7d4411798c6938adc9daaa5     NaN     NaN
# 240534  3f207df678b143eea3cee63160fa8bed     NaN     NaN
# 240535  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 240536  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     NaN
# 240537  9b98b8c7a33c4b65b9aebfe6a799e6d9     NaN     5.0
# 240538  fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 240539  fafdcd668e3743c1bb461111dcafc2a4     NaN     NaN
# 240540  fafdcd668e3743c1bb461111dcafc2a4     NaN     2.0
# 240541                               NaN   17.88     NaN
# 240542                               NaN   21.43     NaN
# 240543                               NaN   18.42     NaN

# %% [markdown]
# We can see that at time 522, one transaction happen and two offer_completed. So, it not possible to associate for what offer, the transaction was actually made. One person can receive multiple offers without even vieweing or completing the first offer. Transactions are not associated with offer_id. For a one single time, one transaction and multiple offer completion can occur. Which actually made the dataset complex to link any offer
# completion with transaction. However, we can try the dataset logic. 1. Check duration after offer receive. 2. Offer completion and transaction time should be same.

# %%
#get df_received
df_received=df_sorted[df_sorted.event=="offer received"]
df_received.rename(columns={'time': 'rcv_time'}, inplace=True)
df_received = df_received[['customer_id', 'rcv_time', 'offer_id']]
print(df_received.shape)
df_received.head()
# Out:
# (66501, 3)
#                         customer_id  rcv_time  \
# 0  0009655768c64bdeb2e877511632db8f       576
# 2  0009655768c64bdeb2e877511632db8f       336
# 4  0009655768c64bdeb2e877511632db8f       168
# 6  0009655768c64bdeb2e877511632db8f       408
# 9  0009655768c64bdeb2e877511632db8f       504
#
#                            offer_id
# 0  2906b810c7d4411798c6938adc9daaa5
# 2  3f207df678b143eea3cee63160fa8bed
# 4  5a8bc65990b245e5a138643cd4eb9837
# 6  f19421c1d4aa40978ebb69ca19b0e20d
# 9  fafdcd668e3743c1bb461111dcafc2a4

# %%
#get df_viewed
df_viewed=df_sorted[df_sorted.event=="offer viewed"]
df_viewed.rename(columns={'time': 'view_time'}, inplace=True)
df_viewed = df_viewed[['customer_id', 'view_time', 'offer_id']]
print(df_viewed.shape)
df_viewed.head()
# Out:
# (49860, 3)
#                          customer_id  view_time  \
# 3   0009655768c64bdeb2e877511632db8f        372
# 5   0009655768c64bdeb2e877511632db8f        192
# 8   0009655768c64bdeb2e877511632db8f        456
# 11  0009655768c64bdeb2e877511632db8f        540
# 21  0011e0d4e6b944f998e987f904e8c1e5        432
#
#                             offer_id
# 3   3f207df678b143eea3cee63160fa8bed
# 5   5a8bc65990b245e5a138643cd4eb9837
# 8   f19421c1d4aa40978ebb69ca19b0e20d
# 11  fafdcd668e3743c1bb461111dcafc2a4
# 21  0b1e1539f2cc45b7b9fa7c272da2e1d7

# %%
#merge df_received and viewed
df_rcv_view=pd.merge(df_received,df_viewed, on=["customer_id", "offer_id"],how="left")
print(df_rcv_view.shape)
print(df_rcv_view.duplicated().sum()) 
df_rcv_view.head()
# Out:
# (82834, 4)
# 0
#                         customer_id  rcv_time  \
# 0  0009655768c64bdeb2e877511632db8f       576
# 1  0009655768c64bdeb2e877511632db8f       336
# 2  0009655768c64bdeb2e877511632db8f       168
# 3  0009655768c64bdeb2e877511632db8f       408
# 4  0009655768c64bdeb2e877511632db8f       504
#
#                            offer_id  view_time
# 0  2906b810c7d4411798c6938adc9daaa5        NaN
# 1  3f207df678b143eea3cee63160fa8bed      372.0
# 2  5a8bc65990b245e5a138643cd4eb9837      192.0
# 3  f19421c1d4aa40978ebb69ca19b0e20d      456.0
# 4  fafdcd668e3743c1bb461111dcafc2a4      540.0

# %%
# can one customer can rcv and view same offer at multiple times?
df_rcv_view[df_rcv_view.duplicated(subset=['customer_id', 'offer_id'], keep=False)]
# Out:
#                             customer_id  rcv_time  \
# 13     0020c2b971eb4e9188eac86d93036a77         0
# 14     0020c2b971eb4e9188eac86d93036a77       336
# 22     003d66b6608740288d6cc97a6903f4f0       168
# 23     003d66b6608740288d6cc97a6903f4f0       168
# 24     003d66b6608740288d6cc97a6903f4f0       408
# ...                                 ...       ...
# 82827  ffff82501cea40309d5fdd7edcca4a07       408
# 82828  ffff82501cea40309d5fdd7edcca4a07       408
# 82829  ffff82501cea40309d5fdd7edcca4a07       576
# 82830  ffff82501cea40309d5fdd7edcca4a07       576
# 82831  ffff82501cea40309d5fdd7edcca4a07       576
#
#                                offer_id  view_time
# 13     fafdcd668e3743c1bb461111dcafc2a4       12.0
# 14     fafdcd668e3743c1bb461111dcafc2a4       12.0
# 22     fafdcd668e3743c1bb461111dcafc2a4      300.0
# 23     fafdcd668e3743c1bb461111dcafc2a4      420.0
# 24     fafdcd668e3743c1bb461111dcafc2a4      300.0
# ...                                 ...        ...
# 82827  2906b810c7d4411798c6938adc9daaa5      414.0
# 82828  2906b810c7d4411798c6938adc9daaa5      582.0
# 82829  2906b810c7d4411798c6938adc9daaa5      354.0
# 82830  2906b810c7d4411798c6938adc9daaa5      414.0
# 82831  2906b810c7d4411798c6938adc9daaa5      582.0
#
# [37784 rows x 4 columns]

# %% [markdown]
# One customer id can receive and view same offers at multiple times. And some cases, we can see view time is before rcv time, which is not logical. So need to get rid of those data

# %%
#get valid rows based on logic that view time should be after rcv_time
df_rcv_view['status'] = np.where(
    df_rcv_view['rcv_time'] <= df_rcv_view['view_time'],
    'valid',
    'invalid'
)
print(df_rcv_view.shape)
df_rcv_view.head()
# Out:
# (82834, 5)
#                         customer_id  rcv_time  \
# 0  0009655768c64bdeb2e877511632db8f       576
# 1  0009655768c64bdeb2e877511632db8f       336
# 2  0009655768c64bdeb2e877511632db8f       168
# 3  0009655768c64bdeb2e877511632db8f       408
# 4  0009655768c64bdeb2e877511632db8f       504
#
#                            offer_id  view_time   status
# 0  2906b810c7d4411798c6938adc9daaa5        NaN  invalid
# 1  3f207df678b143eea3cee63160fa8bed      372.0    valid
# 2  5a8bc65990b245e5a138643cd4eb9837      192.0    valid
# 3  f19421c1d4aa40978ebb69ca19b0e20d      456.0    valid
# 4  fafdcd668e3743c1bb461111dcafc2a4      540.0    valid

# %%
#take only the valid data
df_rcv_view=df_rcv_view[df_rcv_view.status=="valid"]
df_rcv_view = df_rcv_view.drop('status', axis=1)
print(df_rcv_view.shape)
df_rcv_view.head()
# Out:
# (59031, 4)
#                         customer_id  rcv_time  \
# 1  0009655768c64bdeb2e877511632db8f       336
# 2  0009655768c64bdeb2e877511632db8f       168
# 3  0009655768c64bdeb2e877511632db8f       408
# 4  0009655768c64bdeb2e877511632db8f       504
# 5  0011e0d4e6b944f998e987f904e8c1e5       408
#
#                            offer_id  view_time
# 1  3f207df678b143eea3cee63160fa8bed      372.0
# 2  5a8bc65990b245e5a138643cd4eb9837      192.0
# 3  f19421c1d4aa40978ebb69ca19b0e20d      456.0
# 4  fafdcd668e3743c1bb461111dcafc2a4      540.0
# 5  0b1e1539f2cc45b7b9fa7c272da2e1d7      432.0

# %%
#get df_completed
df_completed=df_sorted[df_sorted.event=="offer completed"]
df_completed.rename(columns={'time': 'comp_time'}, inplace=True)
df_completed = df_completed[['customer_id', 'comp_time', 'offer_id']]
print(df_completed.shape)
df_completed.head()
# Out:
# (32070, 3)
#                          customer_id  comp_time  \
# 1   0009655768c64bdeb2e877511632db8f        576
# 7   0009655768c64bdeb2e877511632db8f        414
# 10  0009655768c64bdeb2e877511632db8f        528
# 22  0011e0d4e6b944f998e987f904e8c1e5        576
# 25  0011e0d4e6b944f998e987f904e8c1e5        252
#
#                             offer_id
# 1   2906b810c7d4411798c6938adc9daaa5
# 7   f19421c1d4aa40978ebb69ca19b0e20d
# 10  fafdcd668e3743c1bb461111dcafc2a4
# 22  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 25  2298d6c36e964ae4a3e7e9706d1fb8c2

# %%
#merge df_rcv_view and completed
df_time=pd.merge(df_rcv_view,df_completed, on=["customer_id", "offer_id"],how="left")
print(df_time.shape)
print(df_time.duplicated().sum()) 
df_time.head()
# Out:
# (71675, 5)
# 0
#                         customer_id  rcv_time  \
# 0  0009655768c64bdeb2e877511632db8f       336
# 1  0009655768c64bdeb2e877511632db8f       168
# 2  0009655768c64bdeb2e877511632db8f       408
# 3  0009655768c64bdeb2e877511632db8f       504
# 4  0011e0d4e6b944f998e987f904e8c1e5       408
#
#                            offer_id  view_time  comp_time
# 0  3f207df678b143eea3cee63160fa8bed      372.0        NaN
# 1  5a8bc65990b245e5a138643cd4eb9837      192.0        NaN
# 2  f19421c1d4aa40978ebb69ca19b0e20d      456.0      414.0
# 3  fafdcd668e3743c1bb461111dcafc2a4      540.0      528.0
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7      432.0      576.0

# %% [markdown]
#  A customer can complete an offer without viewing it. It can happen in real life.

# %%
#avg diff between rcv_time and view time
average_difference_view = (df_time['view_time'] - df_time['rcv_time']).mean()
print(average_difference_view)
# Out:
# 78.24142309033833

# %%
#avg diff between view_time and completed time
average_difference_comp = (df_time['comp_time'] - df_time['view_time']).mean()
print(average_difference_comp)
# Out:
# 4.840387950414285

# %%
#avg diff between rcv_time and completed time
avg_diff_rcv_comp = (df_time['comp_time'] - df_time['rcv_time']).mean()
print(avg_diff_rcv_comp)
# Out:
# 90.29327509795105

# %%
#import offer data
df_offer=pd.read_csv("cleaned_offers.csv")
df_offer.head()
# Out:
#                            offer_id     offer_type  difficulty  reward  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo          10      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo          10      10
# 2  3f207df678b143eea3cee63160fa8bed  informational           0       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo           5       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount          20       5
#
#    duration                              channels
# 0         7         ['email', 'mobile', 'social']
# 1         5  ['web', 'email', 'mobile', 'social']
# 2         4            ['web', 'email', 'mobile']
# 3         7            ['web', 'email', 'mobile']
# 4        10                      ['web', 'email']

# %%
#merge df_time and df_offer to add duration
df_time_duration=pd.merge(df_time,df_offer, on="offer_id",how="left")
df_time_duration = df_time_duration[['customer_id', "offer_id","rcv_time","view_time", 'comp_time', 'duration']]
print(df_time_duration.shape)
print(df_time_duration.duplicated().sum()) 
df_time_duration.head()
# Out:
# (71675, 6)
# 0
#                         customer_id                          offer_id  \
# 0  0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 1  0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 4  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
#
#    rcv_time  view_time  comp_time  duration
# 0       336      372.0        NaN         4
# 1       168      192.0        NaN         3
# 2       408      456.0      414.0         5
# 3       504      540.0      528.0        10
# 4       408      432.0      576.0        10

# %%
#convert duration from day to hours
df_time_duration.duration=df_time_duration["duration"]*24
df_time_duration.head()
# Out:
#                         customer_id                          offer_id  \
# 0  0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 1  0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 4  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
#
#    rcv_time  view_time  comp_time  duration
# 0       336      372.0        NaN        96
# 1       168      192.0        NaN        72
# 2       408      456.0      414.0       120
# 3       504      540.0      528.0       240
# 4       408      432.0      576.0       240

# %%
#a valid offer completion time should be lower or equal than rcv_time+duration
df_time_duration["valid_comp_time"]=df_time_duration.rcv_time+df_time_duration.duration
df_time_duration.head()
# Out:
#                         customer_id                          offer_id  \
# 0  0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 1  0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 4  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
#
#    rcv_time  view_time  comp_time  duration  valid_comp_time
# 0       336      372.0        NaN        96              432
# 1       168      192.0        NaN        72              240
# 2       408      456.0      414.0       120              528
# 3       504      540.0      528.0       240              744
# 4       408      432.0      576.0       240              648

# %%
#get valid status column
df_time_duration['status'] = np.where(
    df_time_duration['comp_time'] <= df_time_duration['valid_comp_time'],
    'valid',
    'invalid'
)
df_time_duration.head()
# Out:
#                         customer_id                          offer_id  \
# 0  0009655768c64bdeb2e877511632db8f  3f207df678b143eea3cee63160fa8bed
# 1  0009655768c64bdeb2e877511632db8f  5a8bc65990b245e5a138643cd4eb9837
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 4  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
#
#    rcv_time  view_time  comp_time  duration  valid_comp_time   status
# 0       336      372.0        NaN        96              432  invalid
# 1       168      192.0        NaN        72              240  invalid
# 2       408      456.0      414.0       120              528    valid
# 3       504      540.0      528.0       240              744    valid
# 4       408      432.0      576.0       240              648    valid

# %%
#check status from one customer_id
df_time_duration[df_time_duration.customer_id=="e2127556f4f64592b11af22de27a7932"]
# Out:
#                             customer_id                          offer_id  \
# 63227  e2127556f4f64592b11af22de27a7932  2906b810c7d4411798c6938adc9daaa5
# 63228  e2127556f4f64592b11af22de27a7932  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 63229  e2127556f4f64592b11af22de27a7932  fafdcd668e3743c1bb461111dcafc2a4
#
#        rcv_time  view_time  comp_time  duration  valid_comp_time   status
# 63227         0       18.0        NaN       168              168  invalid
# 63228       408      420.0      522.0       168              576    valid
# 63229       504      522.0      522.0       240              744    valid

# %%
#get valid data only
df_time_valid=df_time_duration[df_time_duration.status=="valid"]
print(df_time_valid.shape)
df_time_valid.head()
# Out:
# (37952, 8)
#                         customer_id                          offer_id  \
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 4  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 8  0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#    rcv_time  view_time  comp_time  duration  valid_comp_time status
# 2       408      456.0      414.0       120              528  valid
# 3       504      540.0      528.0       240              744  valid
# 4       408      432.0      576.0       240              648  valid
# 5       168      186.0      252.0       168              336  valid
# 8       504      516.0      576.0       168              672  valid

# %%
#delete unnecessary columns
df_time_valid = df_time_valid[['customer_id', "offer_id","rcv_time","view_time", 'comp_time']]
print(df_time_valid.shape)
df_time_valid.head()
# Out:
# (37952, 5)
#                         customer_id                          offer_id  \
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 4  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 8  0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#    rcv_time  view_time  comp_time
# 2       408      456.0      414.0
# 3       504      540.0      528.0
# 4       408      432.0      576.0
# 5       168      186.0      252.0
# 8       504      516.0      576.0

# %% [markdown]
# total offer_completion was 32070, however, we got 37952 rows. That means one offer_completion time got attached to multiple rcv_time and view_time

# %%
#offer completion time should be higher than offer receive time
df_time_valid[df_time_valid.rcv_time>=df_time_valid.comp_time]
# Out:
#                             customer_id                          offer_id  \
# 23     003d66b6608740288d6cc97a6903f4f0  fafdcd668e3743c1bb461111dcafc2a4
# 33     004c5799adbf42868b9cff0396190900  f19421c1d4aa40978ebb69ca19b0e20d
# 39     004c5799adbf42868b9cff0396190900  fafdcd668e3743c1bb461111dcafc2a4
# 40     004c5799adbf42868b9cff0396190900  fafdcd668e3743c1bb461111dcafc2a4
# 47     0056df74b63b4298809f0b375a304cf4  2298d6c36e964ae4a3e7e9706d1fb8c2
# ...                                 ...                               ...
# 71667  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 71670  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 71671  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 71672  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 71673  ffff82501cea40309d5fdd7edcca4a07  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#        rcv_time  view_time  comp_time
# 23          408      420.0      384.0
# 33          504      516.0      432.0
# 39          576      648.0      222.0
# 40          576      648.0      576.0
# 47          576      654.0      576.0
# ...         ...        ...        ...
# 71667       408      582.0      384.0
# 71670       576      582.0      384.0
# 71671       576      582.0      414.0
# 71672       576      582.0      576.0
# 71673       504      534.0      504.0
#
# [6868 rows x 5 columns]

# %%
#get valid status column
df_time_valid['status'] = np.where(
    df_time_valid['rcv_time'] <= df_time_valid['comp_time'],
    'valid',
    'invalid'
)
df_time_valid.head()
# Out:
#                         customer_id                          offer_id  \
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 4  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 8  0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#    rcv_time  view_time  comp_time status
# 2       408      456.0      414.0  valid
# 3       504      540.0      528.0  valid
# 4       408      432.0      576.0  valid
# 5       168      186.0      252.0  valid
# 8       504      516.0      576.0  valid

# %%
df_time_valid=df_time_valid[df_time_valid.status=="valid"]
df_time_valid=df_time_valid.drop("status",axis=1)
print(df_time_valid.shape)
df_time_valid.head()
# Out:
# (33133, 5)
#                         customer_id                          offer_id  \
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 4  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 5  0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 8  0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#    rcv_time  view_time  comp_time
# 2       408      456.0      414.0
# 3       504      540.0      528.0
# 4       408      432.0      576.0
# 5       168      186.0      252.0
# 8       504      516.0      576.0

# %%
#add df_transaction to apply 2nd logic [the valid offer_completion will be when transaction time and completed time is same]
#get df_transaction
df_transactions=df_sorted[df_sorted.event=="transaction"]
df_transactions.rename(columns={'time': 'TT_time'}, inplace=True)
df_transactions = df_transactions[['customer_id', 'TT_time']]
print(df_transactions.shape)
df_transactions.head()
# Out:
# (123957, 2)
#                          customer_id  TT_time
# 12  0009655768c64bdeb2e877511632db8f      228
# 13  0009655768c64bdeb2e877511632db8f      414
# 14  0009655768c64bdeb2e877511632db8f      528
# 15  0009655768c64bdeb2e877511632db8f      552
# 16  0009655768c64bdeb2e877511632db8f      576

# %%
#merge df_transactions and df_time_valid
df_time_TT=pd.merge(df_time_valid,df_transactions, on="customer_id",how="left")
print(df_time_TT.shape)
print(df_time_TT.duplicated().sum()) 
df_time_TT.head()
# Out:
# (339464, 6)
# 0
#                         customer_id                          offer_id  \
# 0  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 1  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 4  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
#
#    rcv_time  view_time  comp_time  TT_time
# 0       408      456.0      414.0      228
# 1       408      456.0      414.0      414
# 2       408      456.0      414.0      528
# 3       408      456.0      414.0      552
# 4       408      456.0      414.0      576

# %%
#get valid status column
df_time_TT['status'] = np.where(
    df_time_TT['comp_time'] == df_time_TT['TT_time'],
    'valid',
    'invalid'
)
df_time_TT.head()
# Out:
#                         customer_id                          offer_id  \
# 0  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 1  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 2  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 3  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 4  0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
#
#    rcv_time  view_time  comp_time  TT_time   status
# 0       408      456.0      414.0      228  invalid
# 1       408      456.0      414.0      414    valid
# 2       408      456.0      414.0      528  invalid
# 3       408      456.0      414.0      552  invalid
# 4       408      456.0      414.0      576  invalid

# %%
#get valid data only
df_final_offers=df_time_TT[df_time_TT.status=="valid"]
print(df_final_offers.shape)
print(df_final_offers.duplicated().sum())
df_final_offers.head()
# Out:
# (33133, 7)
# 0
#                          customer_id                          offer_id  \
# 1   0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 10  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 18  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 22  0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 28  0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#     rcv_time  view_time  comp_time  TT_time status
# 1        408      456.0      414.0      414  valid
# 10       504      540.0      528.0      528  valid
# 18       408      432.0      576.0      576  valid
# 22       168      186.0      252.0      252  valid
# 28       504      516.0      576.0      576  valid

# %%
#check status from one customer_id
df_final_offers[df_final_offers.customer_id=="e2127556f4f64592b11af22de27a7932"]
# Out:
#                              customer_id                          offer_id  \
# 297212  e2127556f4f64592b11af22de27a7932  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 297215  e2127556f4f64592b11af22de27a7932  fafdcd668e3743c1bb461111dcafc2a4
#
#         rcv_time  view_time  comp_time  TT_time status
# 297212       408      420.0      522.0      522  valid
# 297215       504      522.0      522.0      522  valid

# %% [markdown]
# There was only one transaction at time 522. However, it became associated with two offer_id which can not happen.

# %%
#number or rows where tt_time is duplicated
df_final_offers[df_final_offers.duplicated(subset=['customer_id', 'offer_id'], keep=False)]
# Out:
#                              customer_id                          offer_id  \
# 89      003d66b6608740288d6cc97a6903f4f0  fafdcd668e3743c1bb461111dcafc2a4
# 107     003d66b6608740288d6cc97a6903f4f0  fafdcd668e3743c1bb461111dcafc2a4
# 131     003d66b6608740288d6cc97a6903f4f0  fafdcd668e3743c1bb461111dcafc2a4
# 171     004c5799adbf42868b9cff0396190900  f19421c1d4aa40978ebb69ca19b0e20d
# 183     004c5799adbf42868b9cff0396190900  f19421c1d4aa40978ebb69ca19b0e20d
# ...                                  ...                               ...
# 339368  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 339386  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 339398  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 339416  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
# 339431  ffff82501cea40309d5fdd7edcca4a07  2906b810c7d4411798c6938adc9daaa5
#
#         rcv_time  view_time  comp_time  TT_time status
# 89           168      300.0      384.0      384  valid
# 107          168      420.0      384.0      384  valid
# 131          408      420.0      504.0      504  valid
# 171          408      408.0      432.0      432  valid
# 183          408      516.0      432.0      432  valid
# ...          ...        ...        ...      ...    ...
# 339368       408      414.0      414.0      414  valid
# 339386       408      414.0      576.0      576  valid
# 339398       408      582.0      414.0      414  valid
# 339416       408      582.0      576.0      576  valid
# 339431       576      582.0      576.0      576  valid
#
# [13759 rows x 7 columns]

# %%
#get valid status column
df_final_offers['status'] = np.where(
    df_final_offers['comp_time'] >= df_final_offers["view_time"],
    'valid',
    'invalid'
)
df_final_offers.head()
# Out:
#                          customer_id                          offer_id  \
# 1   0009655768c64bdeb2e877511632db8f  f19421c1d4aa40978ebb69ca19b0e20d
# 10  0009655768c64bdeb2e877511632db8f  fafdcd668e3743c1bb461111dcafc2a4
# 18  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 22  0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 28  0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
#
#     rcv_time  view_time  comp_time  TT_time   status
# 1        408      456.0      414.0      414  invalid
# 10       504      540.0      528.0      528  invalid
# 18       408      432.0      576.0      576    valid
# 22       168      186.0      252.0      252    valid
# 28       504      516.0      576.0      576    valid

# %%
#get valid data only
df_final_offers=df_final_offers[df_final_offers.status=="valid"]
print(df_final_offers.shape)
print(df_final_offers.duplicated().sum())
df_final_offers.head()
# Out:
# (24172, 7)
# 0
#                          customer_id                          offer_id  \
# 18  0011e0d4e6b944f998e987f904e8c1e5  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 22  0011e0d4e6b944f998e987f904e8c1e5  2298d6c36e964ae4a3e7e9706d1fb8c2
# 28  0011e0d4e6b944f998e987f904e8c1e5  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 35  0020c2b971eb4e9188eac86d93036a77  4d5c57ea9a6940dd891ad53e9dbe8da0
# 39  0020c2b971eb4e9188eac86d93036a77  fafdcd668e3743c1bb461111dcafc2a4
#
#     rcv_time  view_time  comp_time  TT_time status
# 18       408      432.0      576.0      576  valid
# 22       168      186.0      252.0      252  valid
# 28       504      516.0      576.0      576  valid
# 35       408      426.0      510.0      510  valid
# 39         0       12.0       54.0       54  valid

# %%
#check status from one customer_id
df_final_offers[df_final_offers.customer_id=="e2127556f4f64592b11af22de27a7932"]
# Out:
#                              customer_id                          offer_id  \
# 297212  e2127556f4f64592b11af22de27a7932  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 297215  e2127556f4f64592b11af22de27a7932  fafdcd668e3743c1bb461111dcafc2a4
#
#         rcv_time  view_time  comp_time  TT_time status
# 297212       408      420.0      522.0      522  valid
# 297215       504      522.0      522.0      522  valid

# %%
#get df_sorted
df_sorted.head()
# Out:
#                         customer_id gender    age_group   income_group  \
# 0  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 1  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 2  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 3  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 4  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
#
#    membership_year            event  time                          offer_id  \
# 0             2017   offer received   576  2906b810c7d4411798c6938adc9daaa5
# 1             2017  offer completed   576  2906b810c7d4411798c6938adc9daaa5
# 2             2017   offer received   336  3f207df678b143eea3cee63160fa8bed
# 3             2017     offer viewed   372  3f207df678b143eea3cee63160fa8bed
# 4             2017   offer received   168  5a8bc65990b245e5a138643cd4eb9837
#
#    amount  reward
# 0     NaN     NaN
# 1     NaN     2.0
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN

# %%
#get df_completed
df_completed=df_sorted[df_sorted.event=="offer completed"]
print(df_completed.shape)
df_completed.head()
# Out:
# (32070, 10)
#                          customer_id gender         age_group   income_group  \
# 1   0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 7   0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 10  0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 22  0011e0d4e6b944f998e987f904e8c1e5      O  Middle Age Adult  Middle Income
# 25  0011e0d4e6b944f998e987f904e8c1e5      O  Middle Age Adult  Middle Income
#
#     membership_year            event  time                          offer_id  \
# 1              2017  offer completed   576  2906b810c7d4411798c6938adc9daaa5
# 7              2017  offer completed   414  f19421c1d4aa40978ebb69ca19b0e20d
# 10             2017  offer completed   528  fafdcd668e3743c1bb461111dcafc2a4
# 22             2018  offer completed   576  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 25             2018  offer completed   252  2298d6c36e964ae4a3e7e9706d1fb8c2
#
#     amount  reward
# 1      NaN     2.0
# 7      NaN     5.0
# 10     NaN     2.0
# 22     NaN     5.0
# 25     NaN     3.0

# %%
#get df_transaction
df_transaction=df_sorted[df_sorted.event=="transaction"]
print(df_transaction.shape)
df_transaction.head()
# Out:
# (123957, 10)
#                          customer_id gender    age_group   income_group  \
# 12  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 13  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 14  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 15  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
# 16  0009655768c64bdeb2e877511632db8f      M  Young Adult  Middle Income
#
#     membership_year        event  time offer_id  amount  reward
# 12             2017  transaction   228      NaN   22.16     NaN
# 13             2017  transaction   414      NaN    8.57     NaN
# 14             2017  transaction   528      NaN   14.11     NaN
# 15             2017  transaction   552      NaN   13.56     NaN
# 16             2017  transaction   576      NaN   10.27     NaN

# %%
#get rows where transaction time and completed time is same
matching_pairs = pd.merge(
    df_completed[['customer_id', 'time']].drop_duplicates(),
    df_transaction[['customer_id', 'time']].drop_duplicates(),
    on=['customer_id', 'time'],
    how='inner'
)
matching_pairs
# Out:
#                             customer_id  time
# 0      0009655768c64bdeb2e877511632db8f   576
# 1      0009655768c64bdeb2e877511632db8f   414
# 2      0009655768c64bdeb2e877511632db8f   528
# 3      0011e0d4e6b944f998e987f904e8c1e5   576
# 4      0011e0d4e6b944f998e987f904e8c1e5   252
# ...                                 ...   ...
# 29576  ffff82501cea40309d5fdd7edcca4a07   384
# 29577  ffff82501cea40309d5fdd7edcca4a07   414
# 29578  ffff82501cea40309d5fdd7edcca4a07   576
# 29579  ffff82501cea40309d5fdd7edcca4a07   504
# 29580  ffff82501cea40309d5fdd7edcca4a07    60
#
# [29581 rows x 2 columns]

# %%
#filter df_transaction to get offer_related transaction
df_offer_tran = pd.merge(df_transaction, matching_pairs, on=['customer_id', 'time'], how='inner')
print(df_offer_tran.shape)
df_offer_tran.head()
# Out:
# (29581, 10)
#                         customer_id gender         age_group   income_group  \
# 0  0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 1  0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 2  0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 3  0011e0d4e6b944f998e987f904e8c1e5      O  Middle Age Adult  Middle Income
# 4  0011e0d4e6b944f998e987f904e8c1e5      O  Middle Age Adult  Middle Income
#
#    membership_year        event  time offer_id  amount  reward
# 0             2017  transaction   414      NaN    8.57     NaN
# 1             2017  transaction   528      NaN   14.11     NaN
# 2             2017  transaction   576      NaN   10.27     NaN
# 3             2018  transaction   252      NaN   11.93     NaN
# 4             2018  transaction   576      NaN   22.05     NaN

# %%
#total offer related transaction amount
df_offer_tran.amount.sum()
# Out:
# np.float64(606355.75)

# %%
#transaction amount based on gender
offer_transaction_amount_gender=df_offer_tran.groupby("gender")["amount"].sum()
print(offer_transaction_amount_gender)
# Out:
# gender
# F    312028.64
# M    285536.88
# O      8790.23
# Name: amount, dtype: float64

# %%
#average transaciton amount by gender
gender_count= df_offer_tran.groupby("gender")["customer_id"].nunique()
avg_trans_gender=offer_transaction_amount_gender/gender_count.sort_values(ascending=False)
print(avg_trans_gender)
# Out:
# gender
# F    57.879547
# M    44.503878
# O    49.107430
# dtype: float64

# %%
#no. of transaction based on gender
number_of_trans_gender=df_offer_tran.groupby("gender")["event"].size().sort_values(ascending=False)
print(number_of_trans_gender)
# Out:
# gender
# M    15047
# F    14074
# O      460
# Name: event, dtype: int64

# %%
#average transaction value by gender
avg_transaction_value_gender=df_offer_tran.groupby("gender")["amount"].mean()
print(avg_transaction_value_gender)
# Out:
# gender
# F    22.170573
# M    18.976333
# O    19.109196
# Name: amount, dtype: float64

# %%
#transaction amount based on age_group
transaction_amount_age_group=df_offer_tran.groupby("age_group")["amount"].sum().sort_values(ascending=False)
print(transaction_amount_age_group)
# Out:
# age_group
# Older Adult         242947.70
# Senior              149380.68
# Middle Age Adult    108934.62
# Young Adult          52583.33
# Elderly              52509.42
# Name: amount, dtype: float64

# %%
#average transaciton amount by age_group
age_group_count= df_offer_tran.groupby("age_group")["customer_id"].nunique()
avg_trans_age_group=transaction_amount_age_group/age_group_count.sort_values(ascending=False)
print(avg_trans_age_group)
# Out:
# age_group
# Older Adult         55.888590
# Senior              57.146396
# Middle Age Adult    43.889855
# Young Adult         32.803075
# Elderly             55.861085
# dtype: float64

# %%
#no. of transaction based on age_group
number_of_trans_age_group=df_offer_tran.groupby("age_group")["event"].size().sort_values(ascending=False)
print(number_of_trans_age_group)
# Out:
# age_group
# Older Adult         10906
# Senior               6544
# Middle Age Adult     6117
# Young Adult          3648
# Elderly              2366
# Name: event, dtype: int64

# %%
#average transaction value by age_group
avg_transaction_value_age_group=df_offer_tran.groupby("age_group")["amount"].mean().sort_values(ascending=False)
print(avg_transaction_value_age_group)
# Out:
# age_group
# Senior              22.827121
# Older Adult         22.276518
# Elderly             22.193331
# Middle Age Adult    17.808504
# Young Adult         14.414290
# Name: amount, dtype: float64

# %%
#transaction amount based on membership year
transaction_amount_year=df_offer_tran.groupby("membership_year")["amount"].sum().sort_values(ascending=False)
print(transaction_amount_year)
# Out:
# membership_year
# 2017    229763.64
# 2016    173249.20
# 2018     94241.96
# 2015     82172.29
# 2014     19304.66
# 2013      7624.00
# Name: amount, dtype: float64

# %%
#transaction amount based on income_group
transaction_amount_income_group=df_offer_tran.groupby("income_group")["amount"].sum().sort_values(ascending=False)
print(transaction_amount_income_group)
# Out:
# income_group
# Middle Income    333084.10
# High Income      220936.44
# Low Income        52335.21
# Name: amount, dtype: float64

# %%
#average transaciton amount by age_group
income_group_count= df_offer_tran.groupby("income_group")["customer_id"].nunique()
avg_trans_income_group=transaction_amount_income_group/income_group_count.sort_values(ascending=False)
print(avg_trans_income_group)
# Out:
# income_group
# Middle Income    46.044249
# High Income      78.429691
# Low Income       27.046620
# dtype: float64

# %%
#no. of transaction based on income_group
number_of_trans_income_group=df_offer_tran.groupby("income_group")["event"].size().sort_values(ascending=False)
print(number_of_trans_income_group)
# Out:
# income_group
# Middle Income    17956
# High Income       7452
# Low Income        4173
# Name: event, dtype: int64

# %%
#average transaction value by income_group
avg_transaction_value_income_group=df_offer_tran.groupby("income_group")["amount"].mean().sort_values(ascending=False)
print(avg_transaction_value_income_group)
# Out:
# income_group
# High Income      29.647939
# Middle Income    18.550017
# Low Income       12.541387
# Name: amount, dtype: float64

# %%
#get df_completed
df_completed.drop("amount",axis=1,inplace=True)
df_completed.head()
# Out:
#                          customer_id gender         age_group   income_group  \
# 1   0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 7   0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 10  0009655768c64bdeb2e877511632db8f      M       Young Adult  Middle Income
# 22  0011e0d4e6b944f998e987f904e8c1e5      O  Middle Age Adult  Middle Income
# 25  0011e0d4e6b944f998e987f904e8c1e5      O  Middle Age Adult  Middle Income
#
#     membership_year            event  time                          offer_id  \
# 1              2017  offer completed   576  2906b810c7d4411798c6938adc9daaa5
# 7              2017  offer completed   414  f19421c1d4aa40978ebb69ca19b0e20d
# 10             2017  offer completed   528  fafdcd668e3743c1bb461111dcafc2a4
# 22             2018  offer completed   576  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 25             2018  offer completed   252  2298d6c36e964ae4a3e7e9706d1fb8c2
#
#     reward
# 1      2.0
# 7      5.0
# 10     2.0
# 22     5.0
# 25     3.0

# %%
#total reward
df_completed.reward.sum()
# Out:
# np.float64(158630.0)

# %%
#offer completion based on genders
df_completed.gender.value_counts()
# Out:
# gender
# M    16259
# F    15316
# O      495
# Name: count, dtype: int64

# %%
#offer completion based on age_group
df_completed.age_group.value_counts()
# Out:
# age_group
# Older Adult         11898
# Senior               7127
# Middle Age Adult     6558
# Young Adult          3889
# Elderly              2598
# Name: count, dtype: int64

# %%
#offer completion based on membership year
df_completed.membership_year.value_counts()
# Out:
# membership_year
# 2017    11987
# 2016     8836
# 2018     5119
# 2015     4262
# 2014     1308
# 2013      558
# Name: count, dtype: int64

# %%
#offer completion based on income_group
df_completed.income_group.value_counts()
# Out:
# income_group
# Middle Income    19403
# High Income       8222
# Low Income        4445
# Name: count, dtype: int64

# %%
#how many transaction from offers
df_final.event.value_counts()

# %%
#total spend for transaction
df_final["amount"].sum()

# %%
#total reward 
df_final["reward"].sum()

# %%
#import offer data
df_offer=pd.read_csv("cleaned_offers.csv")
df_offer.head()

# %%
# Convert the numerical columns to strings before concatenating
df_offer['difficulty'] = df_offer['difficulty'].astype(str)
df_offer['reward'] = df_offer['reward'].astype(str)
df_offer['duration'] = df_offer['duration'].astype(str)

# Create the new column by concatenating the strings with hyphens
df_offer['offer_key'] = (
    df_offer['offer_type'] + '-' + 
    df_offer['difficulty'] + '-' + 
    df_offer['reward'] + '-' + 
    df_offer['duration']
)

# Display the DataFrame with the new column
print("DataFrame with the new 'offer_key' column:")
print(df_offer[['offer_id', 'offer_key']].head())

# %%
#load df_offer
df_offer.head()

# %%
#merge df_final and df_offer
#merge df_customer and df_event
df_final_offers = pd.merge(df_final, df_offer, on='offer_id', how='left')
df_final_offers.head()

# %%
#initial_report of df_final_offers
initial_report(df_final_offers)

# %%
#drop reward_y and rename reward_x to reward
df_final_offers = df_final_offers.drop(columns=['reward_y'])
df_final_offers.rename(columns={'reward_x': 'reward'}, inplace=True)
df_final_offers.head()

# %%
#which offer type was more succesful
df_final_offers.offer_type.value_counts()

# %%
#which offer key was more succesful
df_final_offers.offer_key.value_counts()
